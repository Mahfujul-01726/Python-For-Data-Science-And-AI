# %% [markdown]
# ![Day1.png](data:image/png;base64,...)

# %% [markdown]
# ![Exploring a Topic in Google Colab - visual selection.png](data:image/png;base64,...)

# %% [markdown]
# # Addition

# %%
5+3
# Out:
# 8

# %% [markdown]
# ## addition1

# %%
print("mahfujul")
# Out:
# mahfujul

# %% [markdown]
# # Python Multiplication

# %%
# Example of multiplication in Python
result = 5 * 3
print(result)

# You can also multiply variables
num1 = 10
num2 = 4
product = num1 * num2
print(product)
# Out:
# 15
# 40
